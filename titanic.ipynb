# %%
import pandas as pd
import numpy as np

df = pd.read_csv("titanic.csv", delimiter = ",")

# %%
print(df[["Age", "Sex"]].head(5))
# Out:
#     Age     Sex
# 0  22.0    male
# 1  38.0  female
# 2  26.0  female
# 3  35.0  female
# 4  35.0    male

# %%
df["Realtives"] = df["SibSp"] + df["Parch"] 
print(len(df[~df["Realtives"].isin([0])]))
print(len(df[df["Embarked"].isin(["S"])]))
# Out:
# 354
# 644

# %%
surv = len(df[df["Survived"].isin([1])])
not_surv = len(df[df["Survived"].isin([0])])
print(f"Survived: {surv}")
print(f"Not survived: {not_surv}")
# Out:
# Survived: 342
# Not survived: 549

# %%
dct = {1 : "Elitarii", 2 : "Srednenkiy", 3 : "Nishuk"}

df = df.replace({"Pclass" : dct})

df["Fare_bin"] = "Dorogo bogato"
df.loc[(df.Fare < 20), "Fare_bin"] = "Mog by i potratica"

df = df.dropna()
df = df.reset_index()
df
# Out:
#      index  PassengerId  Survived    Pclass  \
# 0        1            2         1  Elitarii
# 1        3            4         1  Elitarii
# 2        6            7         0  Elitarii
# 3       10           11         1    Nishuk
# 4       11           12         1  Elitarii
# ..     ...          ...       ...       ...
# 178    871          872         1  Elitarii
# 179    872          873         0  Elitarii
# 180    879          880         1  Elitarii
# 181    887          888         1  Elitarii
# 182    889          890         1  Elitarii
#
#                                                   Name     Sex   Age  SibSp  \
# 0    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 1         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 2                              McCarthy, Mr. Timothy J    male  54.0      0
# 3                      Sandstrom, Miss. Marguerite Rut  female   4.0      1
# ...
