# %%
# !pip install stop-words
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np
import pandas as pd
import seaborn as sns
from wordcloud import WordCloud
from stop_words import get_stop_words

df=pd.read_csv('staff_diplom.csv', delimiter=';')
dict1 = dict()
dict1['теория игр'] = {'игр', 'теоретико-игров', 'стратег', 'вероятностн', 'логик', 'событ', 'байесовск'}
dict1['теория управления'] = {'управлени', 'учет', 'управляем'}
dict1['физические задачи'] = {'частиц', 'катод', 'состоян', 'ускоритель', 'космическ', 'спутник', 'сигнал', 'цеп', 'шкал', 'измерен', 'спутников', 'реактивн', 'газопровод', 'волн', 'галактик', 'цилиндрическ', 'детектирован', 'электрон', 'кинетическ', 'магнитн', 'радионуклидн', 'деформац', 'диодн', 'либраци', 'звёздн', 'ускорительн', 'физик', 'звезд', 'напряжен', 'твёрд', 'оптическ', 'звук', 'желез', 'радиоэлектронн', 'температур', 'газ', 'мощност', 'солнечн', 'гравитационн', 'нефть', 'квантов', 'электромагнитн', 'датчик', 'солнце-земля', 'лабораторн', 'шум', 'вакуумн'}
dict1['вычислительные методы'] = {'численн', 'вычислительн', 'пакет', 'метод', 'погрешност', 'matlab'}
dict1['математическое моделирование'] = {'моделирован', 'модел', 'проектирован', 'математик'}
dict1['медико-биологические системы'] = {'морск', 'медицинск', 'заболеван', 'больн', 'кровь', 'биологическ', 'мозг', 'заболеваем', 'эпидем', 'пациент', 'грипп', 'глаз', 'зрение', 'популяц', 'генетическ', 'инфаркт', 'миокард', 'иммунн', 'летательн', 'возраст', 'медико-биологическ', 'эволюционн', 'операционн', 'лечен', 'орган', 'диагноз', 'вирус', 'медицин', 'вирусн', 'онкологическ', 'психологическ', 'опухоль', 'профилактик', 'болезн', 'волчанк', 'эпидемическ'}
dict1['экономические системы'] = {'предприят', 'рынок', 'риск', 'экономическ', 'финансов', 'организац', 'инвестиционн', 'страхован', 'эмиссионн', 'кредитн', 'многоцелев', 'цен', 'экономик', 'регресс', 'банк', 'страхов', 'затрат', 'налогов', 'фондов', 'торгов', 'ценообразован', 'повышен', 'товар', 'фирма', 'кооперац', 'недвижимость', 'торговл', 'налог', 'банковск', 'ценн', 'бумаг', 'коммерческ', 'продукц', 'портфел', 'акци', 'бизнес', 'продажа', 'инвестиц', 'аукцион', 'стоимость', 'валютн', 'рекламн', 'пенсионн', 'маркетинг', 'покупатель', 'коррупц', 'прибыль', 'макроэкономическ', 'договор', 'коррупционн', 'биржа', 'спрос', 'экономичн', 'валют', 'капитал', 'эконометрическ', 'банкомат', 'транзакц', 'денежн'}
dict1['технологии программирования'] = {'сеть', 'программн', 'компьютерн', 'программирован', 'код', 'библиотек', 'высокопроизводительн', 'блокчейн', 'grid', 'cuda'}
dict1['графика'] = {'трёхмерн', 'виртуальн', 'видеопоток', 'графическ', 'визуализац', '3d', 'видео', 'график', '3d-реконструкц', '3d-модель'}
dict1['разработка'] = {'пользователь', 'сайт', 'класс', 'разработк', 'интерфейс', 'веб', 'пользовательск', 'вебометрическ', 'облак', 'дескриптор', 'web', 'веб-сайт', 'облачн'}
dict1['алгебра и геометрия'] = {'нелинейн', 'линейн', 'поверхность', 'орбита', 'матрица', 'плоск', 'вектор', 'подвижн', 'матричн', 'коэффициент', 'пространств', 'плоскост', 'сферическ', 'эллиптическ', 'характеристическ', 'многомерн', 'сфера', 'выпукл', 'алгебра', 'геометр', 'дискриминантн', 'одномерн', 'полуплоскост', 'линейно-квадратичн', 'дуг', 'эллипсоид', 'прямоугольн', 'изотропн', 'крив', 'гиперплоскост'}
dict1['машинное обучение'] = {'распознаван', 'обучен', 'нейронн', 'машинн', 'синтез', 'нейросетев', 'обучать', 'эвристическ', 'речь', 'монте-карло', 'речев'}
dict1['искуственный интелект'] = {'интеллектуальн', 'искусственн', 'интеллект'}
dict1['задачи на устойчивость'] = {'устойчивост'}
dict1['автоматизация'] = {'автоматическ', 'стабилизац', 'автоматизированн', 'автоматизаци', 'модифицированн', 'производственн', 'прогноз', 'приближен', 'автономн', 'электрическ', 'регулирован'}
dict1['базы данных'] = {'структур', 'хранени', 'база данн', 'data', 'бинарн'}
dict1['анализ данных'] = {'статистик', 'поисков', 'аналитическ', 'робастн', 'оцениван', 'типологизац', 'вероятностно-статистическ'}
dict1['математический и функциональный анализ'] = {'функц', 'параметр', 'дифференциальн', 'асимптотическ', 'ряд', 'множеств', 'порядок', 'ляпунов', 'аппроксимац', 'параметрическ', 'функционал', 'кутта', 'интегрирован', 'аддитивн', 'рекуррентн', 'последовательн', 'дифференциально-разностн', 'билинейн', 'разбиен', 'нэш', 'экспоненциальн', 'покрытие', 'мультипликативн', 'функциональн', 'интегральн', 'интегрироват', 'интеграл', 'аргумент', 'суперпозиция', 'криволинейн', 'декомпозиц'}
dict1['оптимизация'] = {'оптимизац', 'оптимальн', 'распределен', 'эффективность', 'минимизац', 'планирован', 'эффективн', 'безопасност', 'оптимизационн', 'оптимальност'}
dict1['маршрутизация'] = {'маршрутизац', 'сеть', 'коммивояжёр', 'тополог'}
dict1['транспортные задачи'] = {'транспортн', 'маршрут', 'логистическ', 'поставк', 'регион', 'транспорт', 'карт', 'подводн', 'автомобиль', 'расписан', 'дорог', 'железнодорожн', 'автомобильн', 'путь', 'судно', 'дорожн', 'местност', 'рельеф', 'поставщик', 'координат', 'место', 'перевозк', 'перелёт', 'территор', 'логистик'}
dict1['ПО'] = {'обеспечен', 'обслуживан', 'сервис', 'ПО', 'android', 'фреймворк'}
dict1['робототехника'] = {'робот', 'имитационн', 'квадрокоптер', 'робот-манипулятор', 'прототип', 'робототехник', 'беспилотн'}
dict1['кластеризация'] = {'кластеризац', 'кластерн', 'кластер'}
dict1['механика'] = {'движени', 'динамик', 'тел', 'равновеси', 'колебани', 'объём', 'давлени', 'скорост', 'напряжённо-деформированны', 'эмиттер', 'вращени', 'потенциал', 'волнов', 'маятник', 'механическ', 'механика', 'динамическ', 'сила', 'негладк', 'шарнир', 'момент', 'sm-ядро', 'мера', 'гидродинамик', 'волнен', 'сжати', 'ускорен', 'гемодинамик'}

res = dict()
i=0
for obj in dict1.items():
    for elem in obj[1]:
        res[elem] = obj[0]
df['title']=df['title'].str.lower()
series = df['title']
df['tema']="другие темы"
while i<3282:
  for key, value in res.items():
    if df['tema'][i]=="другие темы":
        if key in str(series[i]): 
          df['tema'][i]=value
  i=i+1 
df

df3 = df.groupby(['tema']).size().reset_index(name='count')
df3=df3.sort_values(by='count')
plt.bar(df3['tema'], df3['count'])
plt.xticks(rotation=-90)
plt.show()
print(df3)

df1 = df.groupby(['year']).size().reset_index(name='count')
df1=df1.sort_values(by='count')
plt.bar(df1['year'], df1['count'])
plt.xticks(rotation=-90)
plt.show()

i=1996
while i<2022:
  print()
  print(i)
  df8=df[['tema','year']]
  df8=df8.sort_values(by='year')
  df8=df8[df8['year']==i]
  df8 = df8.groupby(['tema']).size().reset_index(name='count')
  df8=df8.sort_values(by='count')
  plt.bar(df8['tema'], df8['count'])
  plt.xticks(rotation=-90)
  plt.show()
  print(df8)
  i=i+1

df10 = df.groupby(['staffid']).size().reset_index(name='count')
df10=df10.sort_values(by='count')
plt.bar(df10['staffid'], df10['count'])
plt.xticks(rotation=-90)
plt.show()
print(df10)
i=0
while i<6:
  print()
  print(df10['staffid'][i])
  df4=df[df['staffid']==df10['staffid'][i]]
  df4=df4['title']
  df4=pd.DataFrame(df4)
  df4=pd.DataFrame.to_string(df4)
  STOPWORDS_RU = get_stop_words('russian')+['title']
  wordcloud = WordCloud(width = 2000, 
                        height = 1500, 
                        random_state=1, 
                        background_color='black', 
                        margin=20, 
                        colormap='Pastel1', 
                        collocations=False, 
                        stopwords = STOPWORDS_RU).generate(df4)
  plt.imshow(wordcloud)
  plt.show()
  i=i+1


df11 = df.groupby(['department']).size().reset_index(name='count')
df11=df11.sort_values(by='count')
plt.bar(df11['department'], df11['count'])
plt.xticks(rotation=-90)
plt.show()
print(df11)

i=0
while i<6:
  print()
  print(df11['department'][i])
  df4=df[df['department']==df11['department'][i]]
  df4=df4['title']
  df4=pd.DataFrame(df4)
  df4=pd.DataFrame.to_string(df4)
  STOPWORDS_RU = get_stop_words('russian')+['title']
  wordcloud = WordCloud(width = 2000, 
                        height = 1500, 
                        random_state=1, 
                        background_color='black', 
                        margin=20, 
                        colormap='Pastel1', 
                        collocations=False, 
                        stopwords = STOPWORDS_RU).generate(df4)
  plt.imshow(wordcloud)
  plt.show()
  i=i+1

i=0
while i<6:
  print()
  print(df3['tema'][i])
  df4=df[df['tema']==df3['tema'][i]]
  df20 = df4.groupby(['staffid']).size().reset_index(name='count')
  df20=df20.sort_values(by='count')
  plt.bar(df20['staffid'], df20['count'])
  plt.xticks(rotation=-90)
  plt.show()
  print(df20)
  i=i+1
i=0
while i<6:
  print()
  print(df3['tema'][i])
  df4=df[df['tema']==df3['tema'][i]]
  df30 = df4.groupby(['department']).size().reset_index(name='count')
  df30=df30.sort_values(by='count')
  plt.bar(df30['department'], df30['count'])
  plt.xticks(rotation=-90)
  plt.show()
  print(df30)
  i=i+1
i=0
df2=df['student']
ch = ' '
while i<3282:
  df2[i] = str(df2[i]).split(ch, 1)[0]
  i=i+1
df2=pd.DataFrame(df2)
df2=pd.DataFrame.to_string(df2)
STOPWORDS_RU = get_stop_words('russian')+['NaN']
wordcloud = WordCloud(width = 2000, 
                      height = 1500, 
                      random_state=1, 
                      background_color='black', 
                      margin=20, 
                      colormap='Pastel1', 
                      collocations=False, 
                      stopwords = STOPWORDS_RU).generate(df2)
plt.imshow(wordcloud)
plt.show()
# Out:
# Output hidden; open in https://colab.research.google.com to view.
