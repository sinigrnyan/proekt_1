# %%
int a;
# Out:
#   File "<ipython-input-1-56f54d1636df>", line 1
#     int a;
#         ^
# SyntaxError: invalid syntax

# %%
int a;
# Out:
#   File "<ipython-input-2-56f54d1636df>", line 1
#     int a;
#         ^
# SyntaxError: invalid syntax

# %%
int (input) while i<input: while j<input: print(*) j+1 endl i+1

# %%
int (input) while i<input: while j<input: print(*) j+1 endl i+1
# Out:
#   File "<ipython-input-3-9af429fdb4b5>", line 1
#     int (input) while i<input: while j<input: print(*) j+1 endl i+1
#                     ^
# SyntaxError: invalid syntax

# %%
int (input) 
while i<input: 
  while j<input: 
    print(*) 
    j=j+1 
  print(\n) 
  i=i+1
# Out:
#   File "<ipython-input-4-34439adaa1d8>", line 4
#     print(*)
#            ^
# SyntaxError: invalid syntax

# %%
s = int(input()); i=0;
while i<s: print('*'*s); i+=1;
# Out:
# 8
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********

# %%
ss='Abvgd';
print (ss[::-1]);
# Out:
# dgvbA

# %%
ss = 'Ab"vg"d';
print(ss.split('"')[1].split('"')[0])
# Out:
# vg

# %%
ss='7';
print(2*int(ss));
# Out:
# 14

# %%
ss = '3679 679312';
print(ss.split(' ')[1], end=' '); print(ss.split(' ')[0])
# Out:
# 679312 3679

# %%
ss = 'abvgde@mail.ru';
print(ss.split('@')[0]);
# Out:
# abvgde

# %%
s="+7 (812) 134-12-324"
s=s.replace("(", ""); s=s.replace(")", ""); s=s.replace(" ", ""); s=s.replace("-", "")
print(s)
# Out:
# +781213412324

# %%
s='a roza upala na lapu azora'
s=s.replace(" ","");
if s==s[::-1]:
 print('Polindrom')
else:
 print('Ne polindrom')
# Out:
# Polindrom

# %%
s=''; i=1;
while i<123:
 s=s+str(i)
 i=i+1
s=s.replace("9", ""); 
print(s)
# Out:
# 12345678101112131415161718120212223242526272823031323334353637383404142434445464748450515253545556575856061626364656667686707172737475767778780818283848586878880123456781001011021031041051061071081011011111211311411511611711811120121122

# %%
i=100;
while i<1000:
 if i ==((int(str(i)[0]) ** 3) + (int(str(i)[1]) ** 3) + (int(str(i)[2]) ** 3)):
  print(i)
 i=i+1
# Out:
# 153
# 370
# 371
# 407

# %%
i=1; z=0; n=int(input())
while i<n:
 p=len(str(i)); j=i**2
 while p!=0:
  if str(i)[-p]!=str(j)[-p]:
   z=1;
  p=p-1;
 if z==0:
  print(i, end=" "); print(j)
 z=0;
 i=i+1
# Out:
# 1000
# 1 1
# 5 25
# 6 36
# 25 625
# 76 5776
# 376 141376
# 625 390625

# %%
file = open("zhivotiny.txt", "r")
f = open('xyz.txt','w')
lines = file.readlines()
i=0;
for line in lines:
    s = line.split(' ')[1].split(' ')[0]
    for line1 in lines:
     s1=(line1.split(' ')[1].split(' ')[0])
     o=(line.split(' ')[2].split(' ')[0])
     if (s==s1) and (line!=line1) and (o!=(line1.split(' ')[2].split(' ')[0])):
       if o=='female':
        f.write(s + '\n') 
        break        
f.close;      
file.close
# Out:
# <function TextIOWrapper.close>

# %%
import matplotlib.pyplot as plt
import math
import numpy as ny

t=np.linspace(0,1000,10000)
y=lambda t: math.atan(-0.0012*(t**3)+0.4*(t**2)+0.616*t+6120)+0.65*math.sin(0.24*t+1.23)-0.27*math.cos(0.21*t-0.17)-((math.sin(0.34*t+0.16))/(1+0.03*((t-370.5)**2)))
y1=ny.vectorize(y)
plt.xlabel("t")
plt.ylabel("y")
plt.plot(t, y1(t))

# %%
import numpy as np
a=np.array(['Мцыри', 'Преступление и наказание', 'Кортик', 'Бородино', 'Молодая гвардия', 'Евгений Онегин', 'Герой нашего времени', 'Идиот', 'Зойкина квартира', 'Демон', 'Собачье Сердце', 'Сборник романов Достоевского', 'Стихотворения Лермонтова', 'Белая гвардия', 'Мастер и Маргарита', 'Лучшие произведения М.Ю. Лермонтова', 'Горячий снег', 'Дикая собака Динго', 'Беглец', 'Стихотворения Пушкина', 'Василий Теркин', 'Выхожу один я на дорогу', 'Война и Мир', 'Анна Каренина', 'Кинжал',
         'Севастопольские рассказы', 'Бал', 'Ангел', 'Романы Толстого', 'Князь Серебряный','Сердца Трех','По Ком Звонит Колокол', 'Марк Твен', 'Малыш и Карлсон', 'Великий Гетсби', 'Маугли',
         'Мио, Мой Мио', 'На западном фронте без перемен', 'Портрет Дориана Грея', 'Мартин Иден', 'Собор Парижской Богоматери', 'Отверженные', 'Белый Клык', 'Человек, который смеется', 'Детективы Агаты Кристи',
         'Фауст', 'Лучшие стихотворения Киплинга', 'Рубаи Омара Хайяма', 'Сонеты Уильяма Шекспира', 'Гомер: Иллиада', 'Гомер: Одиссея', 'Ворон', 'Уильям Блейк',
         'Гораций', 'Басё', 'Сборник стихотворений Гёте', 'Шиллер. Избраннные произведения', 'Сайгё', 'Сборник Роберта Бернса', 'Омар Хайям'])
print(a)
a[len(a)//2:3*len(a)//4:3]
# Out:
# ['Мцыри' 'Преступление и наказание' 'Кортик' 'Бородино' 'Молодая гвардия'
#  'Евгений Онегин' 'Герой нашего времени' 'Идиот' 'Зойкина квартира'
#  'Демон' 'Собачье Сердце' 'Сборник романов Достоевского'
#  'Стихотворения Лермонтова' 'Белая гвардия' 'Мастер и Маргарита'
#  'Лучшие произведения М.Ю. Лермонтова' 'Горячий снег' 'Дикая собака Динго'
#  'Беглец' 'Стихотворения Пушкина' 'Василий Теркин'
#  'Выхожу один я на дорогу' 'Война и Мир' 'Анна Каренина' 'Кинжал'
#  'Севастопольские рассказы' 'Бал' 'Ангел' 'Романы Толстого'
#  'Князь Серебряный' 'Сердца Трех' 'По Ком Звонит Колокол' 'Марк Твен'
#  'Малыш и Карлсон' 'Великий Гетсби' 'Маугли' 'Мио, Мой Мио'
#  'На западном фронте без перемен' 'Портрет Дориана Грея' 'Мартин Иден'
#  'Собор Парижской Богоматери' 'Отверженные' 'Белый Клык'
#  'Человек, который смеется' 'Детективы Агаты Кристи' 'Фауст'
#  'Лучшие стихотворения Киплинга' 'Рубаи Омара Хайяма'
#  'Сонеты Уильяма Шекспира' 'Гомер: Иллиада' 'Гомер: Одиссея' 'Ворон'
# ...

# %% [markdown]
# import numpy as np
# from matplotlib import pyplot as plt
# data = np.loadtxt("stockholm_tmp.dat", delimiter='\t', dtype=np.string)
# !head -n 3 stockholm_tmp.dat
# x = [x for x in range(len(data[:,3]))]
# plt.plot(x, data[:,3], '-')
#
# plt.title("Sample Visualization")
# plt.show()

# %%
import numpy as np 
from matplotlib import pyplot as plt 
data = np.loadtxt("stockholm_tmp.dat", delimiter='\t', dtype=np.string_)
# !head -n 3 stockholm_tmp.dat 
data=data.tostring()
print(data)
data[3:len(data):7]
# x = [x for x in range(len(data[3:len(data):3])) 
# plt.plot(x, data, '-')
# plt.show()
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
article_read=pd.read_csv('titanic.csv', delimiter=',')
# article_read.loc[(article_read.Pclass == 1), ('Pclass')] = "Elitariy"
# article_read.loc[(article_read.Pclass == 2), ('Pclass')] = "Serednyak"
# article_read.loc[(article_read.Pclass == 3), ('Pclass')] = "Nishugan"
# article_read.loc[(article_read.Fare > 20), ('Cena')] = "Dorogo"
# article_read.loc[(article_read.Fare <= 20), ('Cena')] = "Popret"
sns.violinplot(x = 'Sex', y = "Age", data = article_read[article_read['Survived']==1])
# boxplot = article_read.violinplot(column=['Age' ] , by = ['Sex'])
# article_read[article_read['Survived']==1]
# article_read[['Sex', 'Age']][440:450:2]
# article_read[pd.isnull(article_read['Cabin'])]
# article_read[['Sex', 'Age']]

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
df=pd.read_csv('anime.csv', delimiter=',')
df = df.groupby(['Production']).size().reset_index(name='count')
df=df.sort_values(by='count')
df
# plt.bar(df['Production'], df['count'])
# df

# df.head(10)

# df.columns
# df.dtypes

#df.columns=df.columns.str.lower()
#df.columns = df.columns.str.replace(' ','_')

# df.min()
# df.max()
# df.mean()
# df.std()
# df.median()
# df.quantile(.25)

# df = df.groupby(['Episodes']).size().reset_index(name='count')
# df

# df = df.fillna(0)

# df = df.groupby(['Production']).size().reset_index(name='count')
# df=df.sort_values(by='count')
# plt.bar(df['Production'], df['count'])

# df = df.groupby(['Episodes']).size().reset_index(name='count')
# plt.bar(df['Episodes'], df['count'])

# df = df.groupby(['Source']).size().reset_index(name='count')
# plt.bar(df['Source'], df['count'])

# df = df.groupby(['Theme']).size().reset_index(name='count')
# df=df.sort_values(by='count')
# plt.bar(df['Theme'], df['count'])
# Out:
#                  Production  count
# 215             Zero-G Room      1
# 65   Filmlink International      1
# 64             Fifth Avenue      1
# 63            FLAGSHIP LINE      1
# 62                  FILMONY      1
# ..                      ...    ...
# 36                    Bones     73
# 2              A-1 Pictures     78
# 103                Madhouse     83
# 185                 Sunrise    125
# 197          Toei Animation    130
#
# [224 rows x 2 columns]

# %%
# !pip install stop-words
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np
import pandas as pd
import seaborn as sns
from wordcloud import WordCloud
from stop_words import get_stop_words

df=pd.read_csv('staff_diplom.csv', delimiter=';')

# df = df.groupby(['title']).size().reset_index(name='count')
# df=df.sort_values(by='count')
# plt.bar(df['title'], df['count'])

# df=df[['title','year']]
# df=df.sort_values(by='year')
# df=df[df['year']==2003]
# df

# df = df.groupby(['year']).size().reset_index(name='count')
# df=df.sort_values(by='count')
# plt.bar(df['year'], df['count'])

# df=df[df['staffid']=='petrosjan']
# df=df[df['department']=='mstnmo']
# df=df['title']
# df
# df=pd.DataFrame(df)
# df=pd.DataFrame.to_string(df)
# STOPWORDS_RU = get_stop_words('russian')
# wordcloud = WordCloud(width = 2000, 
#                       height = 1500, 
#                       random_state=1, 
#                       background_color='black', 
#                       margin=20, 
#                       colormap='Pastel1', 
#                       collocations=False, 
#                       stopwords = STOPWORDS_RU).generate(df)
# plt.imshow(wordcloud)

# df=df[['staffid','title']]
# df=df[df['staffid']=='petrosjan']
# df

# df=df[['department','title']]
# df=df[df['department']=='mems']
# df

# df = df.groupby(['department']).size().reset_index(name='count')
# df=df.sort_values(by='count')
# plt.bar(df['department'], df['count'])
# df

# df=df['student']
# df
# df=pd.DataFrame(df)
# df=pd.DataFrame.to_string(df)
# STOPWORDS_RU = get_stop_words('russian')
# wordcloud = WordCloud(width = 2000, 
#                       height = 1500, 
#                       random_state=1, 
#                       background_color='black', 
#                       margin=20, 
#                       colormap='Pastel1', 
#                       collocations=False, 
#                       stopwords = STOPWORDS_RU).generate(df)
# plt.imshow(wordcloud)
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#    department  count
# 1        firs      1
# 2        iiyt      6
# 13     mtmpsu     41
# 14      mtmsu     58
# 3          is     62
# 20         vm     68
# 5        ktpa     77
# 19       umbs     80
# 0         dfs     86
# 18         tu     98
# 15        mud    100
# 10       mses    103
# 21      vmmdt    137
# 17     tsuefa    147
# 12       mter    150
# 8         mes    174
# 9        mmes    178
# 7        mems    206
# 6         kts    255
# 4        kmms    380
# 16         tp    408
# 11     mstnmo    418
